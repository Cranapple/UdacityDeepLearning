# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3081, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'a', 'term', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.756726
# Nearest to they: laughed, rattus, fr, calculation, dez, disrupt, hopwood, tupelo,
# Nearest to would: gauls, judgment, polydor, floyd, exhibitions, lefebvre, dice, departs,
# Nearest to was: invokes, firth, sfor, animistic, riffs, dissolves, leclerc, vermilion,
# Nearest to system: thrilling, astra, compromising, brancusi, greenaway, mcdonnell, ifad, macmillan,
# Nearest to also: ruminants, outpost, generosity, curt, indentations, nominative, cellos, block,
# Nearest to such: grandpa, recruitment, bridge, wartime, dunbar, paula, bosman, meteorologist,
# Nearest to i: gatekeeper, susie, airliners, dwyer, methodist, floresiensis, glorious, tesla,
# Nearest to called: cretans, pineal, catharism, poincar, cryogenics, modernize, frankfurt, succinctly,
# Nearest to UNK: tyrannosaurus, teacher, loyalty, quickly, samyaksam, morbid, quincey, mathias,
# Nearest to been: reflectivity, awk, employing, computability, norbert, poorer, atom, talking,
# Nearest to can: appended, mosquitos, alligators, ge, lilongwe, visualizing, judoka, radar,
# Nearest to had: boutiques, dewitt, icp, disparity, gillies, nacht, beacon, detonating,
# Nearest to time: gloster, strolling, acton, paglia, tenses, lemonade, adhesive, hodgson,
# Nearest to who: honeywell, chelmsford, johannes, martial, interconnects, adema, ayrton, organism,
# Nearest to all: searle, lasor, covering, parables, bbb, subtly, viridian, boulevards,
# Nearest to but: alchemy, dedekind, cunning, enslaved, tristram, submersible, montmartre, spate,
# Average loss at step 2000: 4.365394
# Average loss at step 4000: 3.867007
# Average loss at step 6000: 3.786667
# Average loss at step 8000: 3.685502
# Average loss at step 10000: 3.614535
# Nearest to they: he, it, not, who, there, we, she, still,
# Nearest to would: can, may, might, proudest, judgment, must, could, scissors,
# Nearest to was: is, were, had, has, by, been, be, placental,
# Nearest to system: astra, thrilling, macmillan, mcdonnell, abbas, reverse, brancusi, greenaway,
# Nearest to also: it, which, accepted, rebekah, who, often, chimpanzees, he,
# Nearest to such: well, bridge, ezquerra, protruding, grandpa, recruitment, visigoth, dovich,
# Nearest to i: airliners, gatekeeper, dwyer, he, lderlin, cannae, glorious, assemblers,
# Nearest to called: catharism, cryogenics, chiefly, cmu, yastrzemski, filmmakers, small, fenced,
# Nearest to UNK: semicolon, kingship, gls, excluding, morbid, unknowns, ventris, architecture,
# Nearest to been: wines, were, was, nicolas, springer, be, talking, poorer,
# Nearest to can: may, would, must, appended, will, jackass, mosquitos, enjoyment,
# Nearest to had: has, was, have, boutiques, dewitt, were, mules, nacht,
# Nearest to time: breasted, circa, wff, leakey, transcribing, marxist, deals, lemonade,
# Nearest to who: he, honeywell, martial, they, and, adema, leffler, also,
# Nearest to all: authoritarianism, covering, many, viridian, searle, raaf, bakkers, peak,
# Nearest to but: and, submersible, could, only, afterword, shiga, sheng, gilead,
# Average loss at step 12000: 3.604932
# Average loss at step 14000: 3.564570
# Average loss at step 16000: 3.407968
# Average loss at step 18000: 3.458008
# Average loss at step 20000: 3.538417
# Nearest to they: he, we, there, it, who, you, not, she,
# Nearest to would: can, may, might, could, must, will, should, judgment,
# Nearest to was: is, were, had, has, be, did, does, became,
# Nearest to system: astra, thrilling, reverse, macmillan, ifad, controversies, tolerances, abbas,
# Nearest to also: which, not, often, it, who, never, still, already,
# Nearest to such: well, known, these, ezquerra, dovich, uprisings, recruitment, protruding,
# Nearest to i: ii, hallows, airliners, annum, disaster, bram, we, reaper,
# Nearest to called: mmix, tychonoff, bays, cryogenics, operationally, boing, catharism, yastrzemski,
# Nearest to UNK: architecture, pacific, olympic, imap, semitic, menthol, zines, tabulating,
# Nearest to been: become, be, already, were, wines, frankfort, was, springer,
# Nearest to can: may, would, must, will, could, should, might, appended,
# Nearest to had: has, have, were, was, boutiques, mules, teat, ernest,
# Nearest to time: breasted, year, day, transcribing, leakey, circa, issues, lemonade,
# Nearest to who: he, which, they, martial, leffler, she, also, adema,
# Nearest to all: many, authoritarianism, some, spotless, cern, these, aortic, viridian,
# Nearest to but: however, which, that, inspection, only, and, lost, though,
# Average loss at step 22000: 3.502100
# Average loss at step 24000: 3.489323
# Average loss at step 26000: 3.481778
# Average loss at step 28000: 3.480521
# Average loss at step 30000: 3.500598
# Nearest to they: we, there, he, you, it, these, who, not,
# Nearest to would: could, can, may, will, might, must, should, did,
# Nearest to was: is, were, had, has, been, be, became, by,
# Nearest to system: astra, thrilling, reverse, ifad, controversies, nw, systems, mjs,
# Nearest to also: which, still, sometimes, never, often, it, generally, already,
# Nearest to such: well, these, known, many, aga, follows, oppositional, sly,
# Nearest to i: ii, we, they, arcs, you, airliners, hallows, reaper,
# Nearest to called: mmix, tychonoff, feline, persistence, nutcracker, now, on, garber,
# Nearest to UNK: bova, literal, tus, die, almoravides, sitcoms, stationery, pvc,
# Nearest to been: was, become, were, be, already, ever, frankfort, nouakchott,
# Nearest to can: may, would, could, will, must, should, might, shall,
# Nearest to had: has, have, was, were, ernest, mules, wanted, is,
# Nearest to time: year, breasted, day, issues, leakey, actaeon, roundly, ynys,
# Nearest to who: he, which, martial, and, they, leffler, she, oceania,
# Nearest to all: authoritarianism, some, many, these, withhold, manors, aortic, aquaculture,
# Nearest to but: however, although, though, while, and, which, configurations, there,
# Average loss at step 32000: 3.500436
# Average loss at step 34000: 3.491203
# Average loss at step 36000: 3.454289
# Average loss at step 38000: 3.304074
# Average loss at step 40000: 3.426463
# Nearest to they: we, he, you, there, it, not, she, these,
# Nearest to would: will, could, can, may, might, must, should, did,
# Nearest to was: is, had, has, became, were, been, placental, be,
# Nearest to system: systems, thrilling, astra, reverse, tolerances, alphabetical, golem, estuaries,
# Nearest to also: which, still, often, sometimes, generally, never, now, already,
# Nearest to such: well, known, these, follows, few, oppositional, certain, sly,
# Nearest to i: we, ii, you, they, t, he, annum, arcs,
# Nearest to called: treat, named, feline, mmix, garber, known, now, crossed,
# Nearest to UNK: b, preset, deut, and, manchu, persepolis, nadu, archduke,
# Nearest to been: become, be, was, already, were, nouakchott, ever, frankfort,
# Nearest to can: may, could, will, would, must, should, shall, might,
# Nearest to had: has, have, was, were, mules, ernest, teat, uttered,
# Nearest to time: year, breasted, day, valiant, period, circa, way, transcribing,
# Nearest to who: he, which, leffler, they, oceania, that, she, martial,
# Nearest to all: authoritarianism, many, these, both, each, enjoyable, saskatoon, identical,
# Nearest to but: however, though, although, and, when, it, while, afterword,
# Average loss at step 42000: 3.436237
# Average loss at step 44000: 3.453133
# Average loss at step 46000: 3.446184
# Average loss at step 48000: 3.355445
# Average loss at step 50000: 3.383499
# Nearest to they: we, he, there, you, she, it, these, not,
# Nearest to would: will, could, may, can, might, should, must, did,
# Nearest to was: is, has, were, became, had, been, by, be,
# Nearest to system: systems, thrilling, tolerances, astra, reverse, alphabetical, pierrot, golem,
# Nearest to also: often, still, which, generally, now, sometimes, never, extensively,
# Nearest to such: well, these, known, follows, few, many, certain, evangelica,
# Nearest to i: ii, we, you, hallows, annum, they, t, kirkwood,
# Nearest to called: garber, named, incarceration, treat, feline, surveyors, de, expects,
# Nearest to UNK: kinnock, nyasa, shimizu, jones, immanence, persepolis, wakizashi, gateways,
# Nearest to been: become, were, was, already, be, nouakchott, had, wines,
# Nearest to can: may, could, will, would, must, should, might, shall,
# Nearest to had: has, have, having, was, were, mules, uttered, wanted,
# Nearest to time: year, way, day, breasted, case, period, accessing, circa,
# Nearest to who: he, which, they, leffler, she, generally, also, there,
# Nearest to all: both, authoritarianism, each, some, terms, many, these, identical,
# Nearest to but: however, though, although, when, and, while, than, eurydice,
# Average loss at step 52000: 3.437765
# Average loss at step 54000: 3.429778
# Average loss at step 56000: 3.436207
# Average loss at step 58000: 3.390911
# Average loss at step 60000: 3.393321
# Nearest to they: we, there, you, he, she, not, it, i,
# Nearest to would: will, could, may, can, might, must, should, did,
# Nearest to was: is, had, became, were, has, although, been, does,
# Nearest to system: systems, astra, tolerances, thrilling, alphabetical, process, unit, golem,
# Nearest to also: still, now, generally, often, sometimes, which, never, already,
# Nearest to such: well, these, many, known, follows, including, protruding, sly,
# Nearest to i: ii, we, you, they, hallows, iii, t, arcs,
# Nearest to called: named, known, feline, used, referred, incarceration, pall, shigeru,
# Nearest to UNK: conrad, prequel, aung, regenerate, wainwright, oyster, procurement, cocaine,
# Nearest to been: become, be, was, already, were, had, caterpillars, nouakchott,
# Nearest to can: may, could, would, will, must, should, might, shall,
# Nearest to had: has, have, was, having, were, uttered, wanted, did,
# Nearest to time: way, case, day, purpose, year, period, breasted, roundly,
# Nearest to who: he, which, that, generally, they, she, subsequently, adema,
# Nearest to all: authoritarianism, some, those, these, many, identical, both, any,
# Nearest to but: however, and, although, though, when, than, kkinen, see,
# Average loss at step 62000: 3.243252
# Average loss at step 64000: 3.255963
# Average loss at step 66000: 3.398404
# Average loss at step 68000: 3.390148
# Average loss at step 70000: 3.357749
# Nearest to they: we, there, he, you, she, it, these, not,
# Nearest to would: will, could, may, can, might, must, should, did,
# Nearest to was: is, had, were, has, became, been, when, although,
# Nearest to system: systems, program, thrilling, alphabetical, tolerances, process, unit, astra,
# Nearest to also: still, now, often, which, generally, sometimes, pedagogue, menstrual,
# Nearest to such: these, well, known, many, certain, follows, few, oppositional,
# Nearest to i: we, ii, you, g, hallows, t, they, rae,
# Nearest to called: named, collins, referred, garber, known, incarceration, touristic, used,
# Nearest to UNK: headshot, homepage, bi, taxable, tokusatsu, rusting, organise, ddo,
# Nearest to been: become, be, already, was, were, had, remained, previously,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to had: has, have, was, having, were, been, wanted, uttered,
# Nearest to time: way, breasted, however, case, year, uan, purpose, event,
# Nearest to who: which, he, they, generally, actually, that, born, leffler,
# Nearest to all: some, many, various, any, both, authoritarianism, those, these,
# Nearest to but: however, although, though, that, which, while, when, than,
# Average loss at step 72000: 3.368535
# Average loss at step 74000: 3.347404
# Average loss at step 76000: 3.311148
# Average loss at step 78000: 3.350547
# Average loss at step 80000: 3.381804
# Nearest to they: we, there, he, you, she, it, progs, soon,
# Nearest to would: will, could, can, may, might, should, must, cannot,
# Nearest to was: is, were, had, became, has, been, legionaries, be,
# Nearest to system: systems, unit, program, digital, thrilling, switching, process, alphabetical,
# Nearest to also: still, now, often, sometimes, which, menstrual, generally, always,
# Nearest to such: well, these, follows, certain, known, few, oppositional, many,
# Nearest to i: we, ii, you, they, iii, g, preparedness, t,
# Nearest to called: named, known, referred, considered, used, fisher, shigeru, collins,
# Nearest to UNK: jones, tokusatsu, smith, salon, smack, stationery, correspondance, chow,
# Nearest to been: become, be, was, already, had, were, remained, previously,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to had: has, have, were, was, having, been, wanted, never,
# Nearest to time: year, breasted, omen, davao, day, way, period, purpose,
# Nearest to who: he, adema, they, actually, still, generally, which, wrangler,
# Nearest to all: both, some, many, various, authoritarianism, every, any, several,
# Nearest to but: however, although, though, while, and, than, see, which,
# Average loss at step 82000: 3.404219
# Average loss at step 84000: 3.411441
# Average loss at step 86000: 3.387295
# Average loss at step 88000: 3.351635
# Average loss at step 90000: 3.365821
# Nearest to they: we, there, he, you, she, it, soon, not,
# Nearest to would: will, could, might, may, can, must, should, did,
# Nearest to was: is, became, had, were, been, has, legionaries, be,
# Nearest to system: systems, unit, process, astra, thrilling, program, theory, switching,
# Nearest to also: still, now, which, often, generally, sometimes, never, then,
# Nearest to such: well, these, follows, certain, known, oppositional, regarded, serves,
# Nearest to i: we, ii, you, g, t, iii, preparedness, f,
# Nearest to called: named, known, considered, used, referred, lucius, touristic, shigeru,
# Nearest to UNK: taxable, iroquois, jacques, barter, cao, yes, reformatory, stationery,
# Nearest to been: become, be, was, already, remained, previously, were, had,
# Nearest to can: could, may, will, must, should, would, might, cannot,
# Nearest to had: has, have, was, having, were, wanted, been, hideki,
# Nearest to time: breasted, year, anticipation, day, period, omen, purpose, however,
# Nearest to who: he, she, which, but, adema, actually, they, generally,
# Nearest to all: many, some, several, various, both, every, those, authoritarianism,
# Nearest to but: however, although, and, while, though, who, he, still,
# Average loss at step 92000: 3.394257
# Average loss at step 94000: 3.256064
# Average loss at step 96000: 3.353660
# Average loss at step 98000: 3.240785
# Average loss at step 100000: 3.355118
# Nearest to they: we, he, there, you, she, it, i, not,
# Nearest to would: will, could, might, may, can, should, must, did,
# Nearest to was: is, became, had, has, been, were, although, does,
# Nearest to system: systems, process, theory, unit, thrilling, astra, program, golem,
# Nearest to also: still, now, often, never, sometimes, generally, which, actually,
# Nearest to such: well, known, these, follows, certain, many, classified, regarded,
# Nearest to i: we, you, ii, they, iii, t, g, preparedness,
# Nearest to called: named, referred, known, dflp, used, considered, shigeru, touristic,
# Nearest to UNK: taxable, isomers, linde, barter, modernised, calico, here, admittedly,
# Nearest to been: become, be, already, was, previously, frankfort, ever, were,
# Nearest to can: could, may, must, will, should, would, might, cannot,
# Nearest to had: has, have, was, having, hideki, wanted, were, is,
# Nearest to time: year, breasted, telangana, way, period, day, controversy, omitting,
# Nearest to who: he, never, actually, that, which, still, adema, often,
# Nearest to all: many, various, every, both, authoritarianism, these, several, multiple,
# Nearest to but: however, although, though, and, while, when, which, reciprocating,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_labels.flatten(), train_labels : batch_data.reshape((-1,1))}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.444976
# Nearest to had: treatises, korfball, agilent, pp, granada, rutles, rematch, haaretz,
# Nearest to many: warp, biblioth, insistence, seas, unconfirmed, explorations, toponyms, chances,
# Nearest to while: drain, pisces, atman, fluency, irish, prologue, nazionale, apologists,
# Nearest to UNK: merciless, foetus, countercult, environmentalists, toro, attendees, pyrrhus, giambattista,
# Nearest to at: notification, closet, weierstrass, marple, eftpos, naci, governs, meridian,
# Nearest to some: brooks, multiverse, reviving, diels, silver, guile, gulls, quijote,
# Nearest to system: goodman, circumstance, ainsworth, dynamo, guidelines, guth, calvinball, hutchinson,
# Nearest to one: placental, lambeau, quarried, levelled, moto, herbert, perceptive, payment,
# Nearest to used: barred, uther, stoppage, brockovich, pumping, compl, semitone, moneo,
# Nearest to was: montoneros, hampering, rider, allegheny, collection, penicillin, usaid, mand,
# Nearest to all: arginine, backfired, coherent, alcor, frits, legislature, palomino, imperator,
# Nearest to as: tambo, reservation, wallpaper, nursia, columbus, destination, mishna, conjunctivitis,
# Nearest to can: england, reproduces, brews, shoreline, stuck, stressing, mahoney, docetism,
# Nearest to war: speaker, exceeds, opanal, rwanda, dialect, saffron, auras, surrounded,
# Nearest to two: gauls, offense, waltz, herc, councilor, priory, navigator, equates,
# Nearest to often: escaped, idiot, governs, urals, darfur, durians, meade, sayfawa,
# Average loss at step 2000: 4.421642
# Average loss at step 4000: 3.920539
# Average loss at step 6000: 3.663550
# Average loss at step 8000: 3.690912
# Average loss at step 10000: 3.660990
# Nearest to had: has, was, have, rematch, xiv, pcs, kri, encourages,
# Nearest to many: some, explorations, several, hacienda, shareholders, radii, migrant, tyrell,
# Nearest to while: cumulative, galtieri, nazionale, habeas, dum, cv, apologists, andalus,
# Nearest to UNK: estuary, ulyanov, essex, bse, pasolini, also, essenes, impermanent,
# Nearest to at: in, for, on, adorned, bulletproof, closet, arm, shook,
# Nearest to some: many, gwadar, these, rcr, multiverse, magnitude, shown, guile,
# Nearest to system: circumstance, goodman, guan, disgraceful, fragment, modernizing, hutchinson, experience,
# Nearest to one: two, three, five, seven, six, four, eight, nine,
# Nearest to used: barred, semitone, known, moneo, brockovich, presume, septuagint, hens,
# Nearest to was: is, has, had, were, by, been, topographic, be,
# Nearest to all: status, stanislavski, apostles, dimaggio, circuits, clients, dishonesty, gonzalez,
# Nearest to as: tambo, ern, abaci, vestments, pleasure, psychologists, was, yakov,
# Nearest to can: may, would, could, stuck, will, to, docetism, spectacle,
# Nearest to war: exceeds, speaker, rwanda, saffron, opanal, victors, gave, surrounded,
# Nearest to two: three, five, four, one, six, zero, seven, eight,
# Nearest to often: it, also, governs, still, there, escaped, cfc, durians,
# Average loss at step 12000: 3.653763
# Average loss at step 14000: 3.628183
# Average loss at step 16000: 3.554674
# Average loss at step 18000: 3.519509
# Average loss at step 20000: 3.500687
# Nearest to had: has, have, was, were, rematch, multiplex, kondratiev, encourages,
# Nearest to many: some, these, several, all, each, radii, other, various,
# Nearest to while: cumulative, yf, though, habeas, cv, nazionale, hypothesize, uk,
# Nearest to UNK: and, pasolini, intelsat, actaeon, jean, mclaughlin, postulates, paul,
# Nearest to at: in, adorned, on, bulletproof, islas, from, for, bash,
# Nearest to some: many, these, gwadar, most, all, several, keenan, other,
# Nearest to system: goodman, circumstance, disgraceful, modernizing, scythian, gotten, songwriting, provincial,
# Nearest to one: two, four, six, eight, three, seven, five, nine,
# Nearest to used: barred, known, septuagint, described, due, stoppage, considered, semitone,
# Nearest to was: is, had, were, has, became, be, been, topographic,
# Nearest to all: many, some, ridiculous, sinatra, any, these, apostles, emf,
# Nearest to as: glazer, simcoe, had, extortion, relegated, by, was, nynorsk,
# Nearest to can: may, would, could, will, might, must, should, cannot,
# Nearest to war: exceeds, victors, dialect, opanal, saffron, speaker, surrounded, bangalore,
# Nearest to two: four, three, five, seven, six, one, eight, nine,
# Nearest to often: sometimes, still, there, also, it, commonly, they, governs,
# Average loss at step 22000: 3.445168
# Average loss at step 24000: 3.520166
# Average loss at step 26000: 3.414739
# Average loss at step 28000: 3.426454
# Average loss at step 30000: 3.383788
# Nearest to had: has, have, was, were, multiplex, when, severan, pcs,
# Nearest to many: some, several, these, various, all, other, such, those,
# Nearest to while: though, but, although, however, weaves, when, cumulative, and,
# Nearest to UNK: conflated, english, j, ero, pierre, american, poet, canadians,
# Nearest to at: in, adorned, islas, closet, from, nullify, on, button,
# Nearest to some: many, these, several, most, other, all, gwadar, those,
# Nearest to system: goodman, disgraceful, songwriting, no, modernizing, scythian, homophobic, hacienda,
# Nearest to one: d, seven, b, six, autosomal, two, verlag, and,
# Nearest to used: considered, barred, described, known, referred, found, explained, made,
# Nearest to was: is, has, had, were, became, when, been, be,
# Nearest to all: many, these, some, both, several, coin, those, ridiculous,
# Nearest to as: glazer, ranger, liu, in, brief, approaches, when, smallpox,
# Nearest to can: may, will, would, could, must, might, cannot, should,
# Nearest to war: dialect, surrounded, exceeds, bangalore, victors, fireball, bricks, guardia,
# Nearest to two: four, three, seven, five, zero, nine, six, eight,
# Nearest to often: sometimes, commonly, still, usually, widely, also, generally, primarily,
# Average loss at step 32000: 3.509319
# Average loss at step 34000: 3.468939
# Average loss at step 36000: 3.465905
# Average loss at step 38000: 3.418585
# Average loss at step 40000: 3.293773
# Nearest to had: has, have, was, were, having, multiplex, severan, belarusians,
# Nearest to many: some, several, these, various, all, those, such, most,
# Nearest to while: although, though, however, when, until, ya, but, abbreviating,
# Nearest to UNK: h, n, harmless, r, int, l, weissmuller, y,
# Nearest to at: in, islas, adorned, within, powdered, closet, on, after,
# Nearest to some: many, these, several, their, various, most, gwadar, those,
# Nearest to system: systems, technology, goodman, network, distributing, whitaker, modernizing, purr,
# Nearest to one: seven, two, six, eight, four, five, three, th,
# Nearest to used: known, described, seen, barred, considered, found, regarded, available,
# Nearest to was: is, has, had, were, became, be, been, extend,
# Nearest to all: both, many, any, each, these, several, some, numismatics,
# Nearest to as: simcoe, approaches, when, durango, glazer, universite, abaci, guerrilla,
# Nearest to can: may, would, could, will, must, might, should, cannot,
# Nearest to war: monetarism, exceeds, bangalore, dialect, victors, bricks, nutrients, rwanda,
# Nearest to two: three, five, seven, four, six, one, eight, zero,
# Nearest to often: sometimes, usually, commonly, widely, still, generally, primarily, now,
# Average loss at step 42000: 3.439740
# Average loss at step 44000: 3.457372
# Average loss at step 46000: 3.471062
# Average loss at step 48000: 3.441263
# Average loss at step 50000: 3.448753
# Nearest to had: has, have, was, having, multiplex, were, kondratiev, severan,
# Nearest to many: some, several, these, all, various, those, most, other,
# Nearest to while: although, when, though, however, where, but, for, before,
# Nearest to UNK: intelsat, rufus, w, r, le, manor, richelieu, sees,
# Nearest to at: in, during, closet, islas, adorned, genitals, on, crookes,
# Nearest to some: many, these, several, most, all, any, various, their,
# Nearest to system: systems, technology, distributing, ainsworth, scythian, provincial, whitaker, antiarrhythmic,
# Nearest to one: seven, two, six, three, four, five, eight, nine,
# Nearest to used: known, described, considered, found, called, added, possible, required,
# Nearest to was: is, has, had, were, when, became, been, topographic,
# Nearest to all: both, many, several, each, some, these, any, disposal,
# Nearest to as: when, glazer, columbus, lafur, approaches, physique, guerrilla, valois,
# Nearest to can: may, would, could, will, must, might, should, cannot,
# Nearest to war: monetarism, pki, rounded, assimilate, bangalore, nutrients, vajrayana, surrounded,
# Nearest to two: five, three, four, six, seven, eight, one, zero,
# Nearest to often: sometimes, usually, commonly, generally, widely, also, still, frequently,
# Average loss at step 52000: 3.379386
# Average loss at step 54000: 3.325385
# Average loss at step 56000: 3.393255
# Average loss at step 58000: 3.405047
# Average loss at step 60000: 3.339746
# Nearest to had: has, have, was, were, having, kondratiev, debra, began,
# Nearest to many: some, several, these, all, various, both, most, those,
# Nearest to while: although, though, when, where, but, however, or, before,
# Nearest to UNK: der, sullivan, dr, ii, dcsd, elevator, king, allis,
# Nearest to at: in, during, on, adorned, closet, blackfoot, within, shook,
# Nearest to some: many, these, several, any, all, most, various, gwadar,
# Nearest to system: systems, technology, method, network, scythian, goodman, provincial, ainsworth,
# Nearest to one: seven, four, three, five, nine, two, six, eight,
# Nearest to used: known, described, considered, referred, added, able, found, available,
# Nearest to was: is, became, had, has, were, when, be, by,
# Nearest to all: both, many, some, several, these, each, various, are,
# Nearest to as: glazer, when, physique, audible, extortion, after, ulster, guerrilla,
# Nearest to can: may, will, could, would, must, should, might, cannot,
# Nearest to war: wars, assimilate, pki, monetarism, vancouver, spassky, airstrip, rounded,
# Nearest to two: three, four, eight, six, seven, five, nine, zero,
# Nearest to often: sometimes, usually, commonly, generally, still, now, frequently, widely,
# Average loss at step 62000: 3.397258
# Average loss at step 64000: 3.403578
# Average loss at step 66000: 3.366392
# Average loss at step 68000: 3.423295
# Average loss at step 70000: 3.377455
# Nearest to had: has, have, was, were, having, debra, severan, kondratiev,
# Nearest to many: several, some, these, various, those, both, all, most,
# Nearest to while: although, though, but, however, when, or, than, before,
# Nearest to UNK: melville, amiable, atone, fence, english, et, visualisation, waals,
# Nearest to at: in, adorned, during, under, blackfoot, within, incredible, on,
# Nearest to some: many, these, several, most, any, those, all, tetrahedron,
# Nearest to system: systems, method, technology, provincial, fluently, process, antiarrhythmic, claude,
# Nearest to one: seven, eight, six, two, four, three, five, nine,
# Nearest to used: known, described, done, found, required, considered, called, spoken,
# Nearest to was: is, has, became, had, were, be, materialistic, when,
# Nearest to all: both, many, some, each, these, various, several, any,
# Nearest to as: vestments, glazer, extortion, removable, battista, penny, jehoiakim, cautioned,
# Nearest to can: will, may, could, would, must, should, cannot, might,
# Nearest to war: wars, assimilate, pki, spassky, monetarism, astrophysics, romanorum, prim,
# Nearest to two: three, four, five, seven, six, eight, nine, zero,
# Nearest to often: sometimes, usually, commonly, generally, still, also, now, normally,
# Average loss at step 72000: 3.235287
# Average loss at step 74000: 3.381377
# Average loss at step 76000: 3.386181
# Average loss at step 78000: 3.274056
# Average loss at step 80000: 3.355306
# Nearest to had: has, have, was, having, were, kondratiev, been, subsequently,
# Nearest to many: some, several, those, these, most, various, all, both,
# Nearest to while: although, though, but, however, when, and, before, aor,
# Nearest to UNK: les, adornment, swaziland, j, elliott, miss, revoke, illusory,
# Nearest to at: adorned, during, incredible, blackfoot, islas, near, powdered, on,
# Nearest to some: many, several, these, all, certain, any, most, humans,
# Nearest to system: systems, method, technology, network, process, ainsworth, applications, namesake,
# Nearest to one: two, seven, three, eight, corrino, five, tutankhamun, nine,
# Nearest to used: known, done, called, required, found, available, referred, stored,
# Nearest to was: is, were, had, became, has, been, by, be,
# Nearest to all: both, various, some, several, many, these, only, disposal,
# Nearest to as: glazer, uua, liddell, financiers, antenna, when, physique, durango,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to war: wars, assimilate, prim, astrophysics, pki, oriental, rays, pauline,
# Nearest to two: three, five, one, eight, four, seven, six, zero,
# Nearest to often: sometimes, usually, commonly, generally, still, frequently, also, normally,
# Average loss at step 82000: 3.348640
# Average loss at step 84000: 3.312126
# Average loss at step 86000: 2.947629
# Average loss at step 88000: 2.911975
# Average loss at step 90000: 3.098763
# Nearest to had: has, have, was, having, were, began, could, severan,
# Nearest to many: some, several, these, those, various, all, both, most,
# Nearest to while: although, though, when, but, however, where, before, and,
# Nearest to UNK: et, cougars, energetically, la, visualisation, simultaneous, abkhazia, menorah,
# Nearest to at: in, during, near, on, under, after, islas, within,
# Nearest to some: many, several, these, any, most, bruises, certain, resulted,
# Nearest to system: systems, method, technology, process, network, unit, provincial, applications,
# Nearest to one: two, corrino, seven, sutra, ussachevsky, four, six, disgusted,
# Nearest to used: known, called, described, required, referred, found, added, done,
# Nearest to was: is, had, became, has, although, were, when, been,
# Nearest to all: both, several, many, these, various, disposal, every, fares,
# Nearest to as: after, nynorsk, when, glazer, became, thermoelectric, physique, lope,
# Nearest to can: could, will, must, would, should, cannot, might, may,
# Nearest to war: wars, pki, astrophysics, assimilate, oriental, prim, vancouver, rays,
# Nearest to two: four, three, five, six, eight, seven, nine, zero,
# Nearest to often: sometimes, usually, generally, commonly, frequently, still, also, actually,
# Average loss at step 92000: 3.185197
# Average loss at step 94000: 3.266352
# Average loss at step 96000: 3.280931
# Average loss at step 98000: 3.277540
# Average loss at step 100000: 3.245272
# Nearest to had: has, have, having, was, were, subsequently, debra, since,
# Nearest to many: some, several, these, those, various, numerous, both, all,
# Nearest to while: although, though, when, before, however, after, but, where,
# Nearest to UNK: sucked, gunned, steinmetz, et, hieroglyphic, biosphere, catv, gens,
# Nearest to at: near, adorned, in, during, bulletproof, superseding, closet, islas,
# Nearest to some: many, several, these, most, bruises, those, any, numerous,
# Nearest to system: systems, method, network, unit, process, applications, technology, provincial,
# Nearest to one: two, three, seven, six, eight, four, corrino, five,
# Nearest to used: done, known, called, described, seen, referred, required, found,
# Nearest to was: is, were, became, had, has, be, been, although,
# Nearest to all: both, many, several, various, these, those, each, disposal,
# Nearest to as: glazer, alongside, nguni, battista, physique, becomes, durango, lope,
# Nearest to can: could, will, would, must, may, might, should, cannot,
# Nearest to war: wars, assimilate, floppy, rays, oriental, exceeds, pki, astrophysics,
# Nearest to two: five, three, four, seven, six, eight, one, zero,
# Nearest to often: usually, sometimes, generally, commonly, frequently, also, typically, still,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
#I think technically you'd have to eval for multiple words, add the outputs and then normalize.
